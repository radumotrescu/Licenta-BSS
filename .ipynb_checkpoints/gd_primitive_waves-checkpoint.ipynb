# %%
import numpy as np
from scipy import signal
import scipy.io.wavfile
import matplotlib.pyplot as plt
import math
from IPython.display import Audio

# %%
np.random.seed(0)
n_samples=500
time = np.linspace(0,8,n_samples)

sample1_data = np.sin(5*time) # Signal 1 : sinusoidal signal
sample2_data = signal.sawtooth(1.0 * np.pi * time) # Signal 2 : saw tooth signal

sample3_data = np.sign(np.sin(3 * time))  # Signal 2 : square signal

# %%
def sigmoid(y):
    g=np.divide(1,np.add(1,np.exp(-y)))
    return g

def gradient(eta, Y, W):
    delW=np.zeros(W.shape)
    Z=sigmoid(Y)
    Id=np.identity(Y.shape[0])
    grad=eta*(Id+np.dot((1-2*Z),Y.T))*W
    return grad

# %%
plt.figure()
plt.plot(sample1_data)
plt.show()
plt.figure()
plt.plot(sample2_data)
plt.show()
plt.figure()
plt.plot(sample3_data)
plt.show()

# %%
med1=sample1_data.std(axis=0)
s1data= sample1_data/med1
med2=sample2_data.std(axis=0)
s2data=sample2_data/med2

med3=sample3_data.std(axis=0)
s3data=sample3_data/med3

orig=np.matrix([s1data,s2data])
n=len(orig)
A=np.random.random([n,n])
#A=np.matrix([[1,1],[3,0.5]])
A=np.matrix([[0.56804456 , 0.92559664],
             [0.07103606 , 0.0871293]])
print("Mixing matrix: \n"+str(A))
X=np.dot(A,orig)
plt.figure()
plt.plot(X.T)
plt.show()
# Out:
# Mixing matrix:
# [[ 0.56804456  0.92559664]
#  [ 0.07103606  0.0871293 ]]

# %%
Audio(data=X[0], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
eta=0.01
eta0=eta
T=1000
corr=1
while abs(corr)>=1.5e-5:
    W=np.random.random([n,n])/100
    print("Initial guessed decomposition matrix: \n"+str(W))
    for i in range(0,num_iter):
        Y=np.dot(W,X)
        delW=gradient(eta,Y,W)
        W+=delW
        eta=eta0/(1+(i/T))
    Y2=np.dot(W,X)
    corr=np.correlate(np.ravel(Y2[0]),np.ravel(Y2[1]))
    print(corr)
# Out:
# Initial guessed decomposition matrix:
# [[ 0.00423655  0.00645894]
#  [ 0.00437587  0.00891773]]
# [  3.24425322e-05]
# Initial guessed decomposition matrix:
# [[ 0.00963663  0.00383442]
#  [ 0.00791725  0.00528895]]
# [  2.26753424e-05]
# Initial guessed decomposition matrix:
# [[ 0.00568045  0.00925597]
#  [ 0.00071036  0.00087129]]
# [  4.89941426e-05]
# Initial guessed decomposition matrix:
# [[ 0.00020218  0.0083262 ]
#  [ 0.00778157  0.00870012]]
# [ -3.50045721e-05]
# Initial guessed decomposition matrix:
# [[ 0.00978618  0.00799159]
#  [ 0.00461479  0.00780529]]
# [ -1.34308794e-06]

# %%
print(W)
Y2=np.dot(W,X)
plt.figure()
plt.plot(Y2[0].T)
plt.show()
plt.figure()
plt.plot(Y2[1].T)
plt.show()
#plt.figure()
#plt.plot(Y2[2].T)
#plt.show()
# Out:
# [[ 0.24488962 -1.87933046]
#  [-0.36606773  3.81286489]]

# %%
Audio(data=Y2[0], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=Y2[1], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=sample1_data, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=sample2_data, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
