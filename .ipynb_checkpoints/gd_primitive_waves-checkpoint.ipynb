# %%
import numpy as np
from scipy import signal
import scipy.io.wavfile
import matplotlib.pyplot as plt
import math
from IPython.display import Audio
from sklearn.decomposition import PCA

# %%
np.random.seed(0)
n_samples=500
time = np.linspace(0,8,n_samples)

sample1_data = np.sin(5*time) # Signal 1 : sinusoidal signal
sample2_data = signal.sawtooth(1.0 * np.pi * time) # Signal 2 : saw tooth signal

sample3_data = np.sign(np.sin(3 * time))  # Signal 2 : square signal

# %%
def sigmoid(y):
    g=np.divide(1,np.add(1,np.exp(-y)))
    return g

def gradient(eta, Y, W):
    delW=np.zeros(W.shape)
    Z=sigmoid(Y)
    Id=np.identity(Y.shape[0])
    grad=eta*(Id+np.dot((1-2*Z),Y.T))*W
    return grad

# %%
plt.figure()
plt.plot(sample1_data)
plt.show()
plt.figure()
plt.plot(sample2_data)
plt.show()
plt.figure()
plt.plot(sample3_data)
plt.show()

# %%
med1=sample1_data.std(axis=0)
s1data= sample1_data/med1
med2=sample2_data.std(axis=0)
s2data=sample2_data/med2

med3=sample3_data.std(axis=0)
s3data=sample3_data/med3

orig=np.matrix([s1data,s2data])
n=len(orig)
A=np.random.random([n,n])
A=np.matrix([[0.56804456 , 0.92559664],
             [0.07103606 , 0.0871293]])
print("Mixing matrix: \n"+str(A))
X=np.dot(A,orig)
print("Correlation coefficient - original data \n" + str(np.corrcoef(s1data,s2data)))
print(np.correlate(np.ravel(s1data),np.ravel(s2data)))
print("Correlation coefficient - mixed data \n" + str(np.corrcoef(X)))
print(np.correlate(np.ravel(X[0]),np.ravel(X[1])))
plt.figure()
plt.plot(X.T)
plt.show()
# Out:
# Mixing matrix:
# [[ 0.56804456  0.92559664]
#  [ 0.07103606  0.0871293 ]]
# Correlation coefficient - original data
# [[ 1.         0.0163405]
#  [ 0.0163405  1.       ]]
# [ 7.96418379]
# Correlation coefficient - mixed data
# [[ 1.          0.99136365]
#  [ 0.99136365  1.        ]]
# [ 61.49054878]

# %%
Audio(data=X[0], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
eta=0.01
eta0=eta
T=1000
corr=1
num_iter=10000
while abs(corr)>=9e-4:
    W=np.random.random([n,n])/10
    norms=np.array([])
    print("Initial guessed decomposition matrix: \n"+str(W))
    for i in range(0,num_iter):
        Y=np.dot(W,X)
        delW=gradient(eta,Y,W)
        W+=delW
        norms=np.append(norms,np.linalg.norm(W))
        eta=eta0/(1+(i/T))
    Y2=np.dot(W,X)
    corr=np.corrcoef(Y2)[1][0]
    print("Correlation coefficient \n" + str(np.corrcoef(Y2)[1][0]))
    print("\n\n")
# Out:
# Initial guessed decomposition matrix:
# [[ 0.04236548  0.06458941]
#  [ 0.04375872  0.0891773 ]]
# Correlation coefficient
# 0.00124292759158
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.09636628  0.03834415]
#  [ 0.0791725   0.05288949]]
# Correlation coefficient
# 0.00091808560419
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.05680446  0.09255966]
#  [ 0.00710361  0.00871293]]
# Correlation coefficient
# 0.00166418953603
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.00202184  0.08326198]
#  [ 0.07781568  0.08700121]]
# Correlation coefficient
# -0.00111681530851
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.09786183  0.07991586]
#  [ 0.04614794  0.07805292]]
# Correlation coefficient
# 9.45053229919e-05

# %%
print(W)
Y2=np.dot(W,X)
plt.figure()
plt.plot(Y2[0].T)
plt.show()
plt.figure()
plt.plot(Y2[1].T)
plt.show()
#plt.figure()
#plt.plot(Y2[2].T)
#plt.show()
# Out:
# [[ 0.24482818 -1.87869056]
#  [-0.36610883  3.8131803 ]]

# %%
Audio(data=Y2[0], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=Y2[1], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=sample1_data, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=sample2_data, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
