# %%
import numpy as np
from scipy import signal
import scipy.io.wavfile
import matplotlib.pyplot as plt
import math
from IPython.display import Audio
from sklearn.decomposition import PCA

# %%
np.random.seed(0)
n_samples=500
time = np.linspace(0,8,n_samples)

sample1_data = np.sin(5*time) # Sinusoidal signal
sample2_data = signal.sawtooth(2.0 * np.pi * time) # Saw tooth signal

# %%
def sigmoid(y):
    g=np.divide(1,np.add(1,np.exp(-y)))
    return g

def gradient(eta, Y, W):
    Z=sigmoid(Y)
    Id=np.identity(Y.shape[0])
    grad=eta*(Id+np.dot((1-2*Z),Y.T))*W
    return grad

# %%
plt.figure()
plt.plot(sample1_data)
plt.show()
plt.figure()
plt.plot(sample2_data)
plt.show()

# %%
med1=sample1_data.std(axis=0)
s1data= sample1_data/med1
med2=sample2_data.std(axis=0)
s2data=sample2_data/med2

print("Correlation coefficient - original data \n" + str(np.corrcoef(s1data,s2data)))

orig=np.matrix([s1data,s2data])
n=len(orig)
A=np.random.random([n,n])
A=np.matrix([[0.56804456 , 0.92559664],
             [0.07103606 , 0.0871293]])
print("Mixing matrix: \n"+str(A))
X=np.dot(A,orig)
print("Correlation coefficient - mixed data \n" + str(np.corrcoef(X)))
plt.figure()
plt.plot(X.T)
plt.show()
# Out:
# Correlation coefficient - original data
# [[ 1.          0.07484149]
#  [ 0.07484149  1.        ]]
# Mixing matrix:
# [[ 0.56804456  0.92559664]
#  [ 0.07103606  0.0871293 ]]
# Correlation coefficient - mixed data
# [[ 1.          0.99226948]
#  [ 0.99226948  1.        ]]

# %%
def costFunc(Y,W):
    Z=sigmoid(Y)
    c1=np.dot(Z.T,1-Z)
    C1=np.log(c1)
    return np.sum(C1)

# %%
eta=0.01
eta0=eta
T=1000
corr=1
num_iter=10000
threshold=0.00000000005
cost=0
prevCost=0
flag=True
while flag==True:
    W=np.random.uniform(0.01,0.1,(n,n))
    print("Initial guessed decomposition matrix: \n"+str(W))
    cost=0
    prevCost=0
    for i in range(0,num_iter):
        Y=np.dot(W,X)
        delW=gradient(eta,Y,W)
        W+=delW
        eta=eta0/(1+(i/T))
        if i==0:
            cost=costFunc(Y,W)
        elif i%10==0:
            prevCost=cost
            cost=costFunc(Y,W)
            if abs(abs(prevCost)-abs(cost)) < threshold:
                flag=False
                #print("X"+str(i))
                break;
    Y2=np.dot(W,X)
    corr=np.corrcoef(Y2)[1][0]
    print("Correlation coefficient \n" + str(np.corrcoef(Y2)[1][0]))
    print("\n\n")
# Out:
# Initial guessed decomposition matrix:
# [[ 0.04812893  0.06813047]
#  [ 0.04938285  0.09025957]]
# Correlation coefficient
# 0.00126950801597
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.09672965  0.04450974]
#  [ 0.08125525  0.05760054]]
# Correlation coefficient
# 0.000988129245413
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06112401  0.0933037 ]
#  [ 0.01639325  0.01784164]]
# Correlation coefficient
# 0.00182376939219
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.01181966  0.08493579]
#  [ 0.08003411  0.08830109]]
# Correlation coefficient
# -0.000772642832188
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.09807565  0.08192427]
#  [ 0.05153314  0.08024763]]
# Correlation coefficient
# 0.000275430929498
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.0206447   0.06759289]
#  [ 0.0229018   0.0950202 ]]
# Correlation coefficient
# 0.00136467311435
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.05696635  0.04731957]
#  [ 0.03381001  0.07968103]]
# Correlation coefficient
# 0.000577799358995
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.05105353  0.06115906]
#  [ 0.01169108  0.06558719]]
# Correlation coefficient
# -0.000483957831934
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06508862  0.06552406]
#  [ 0.09493733  0.07136383]]
# Correlation coefficient
# 0.000647015596024
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.04235571  0.04933288]
#  [ 0.07278681  0.01542029]]
# Correlation coefficient
# 0.000504062661582
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.070009    0.07035741]
#  [ 0.02893443  0.02160337]]
# Correlation coefficient
# 0.00185295880692
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.03838855  0.04273397]
#  [ 0.06131771  0.04947414]]
# Correlation coefficient
# 0.000502864114055
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.09895365  0.01918403]
#  [ 0.02879891  0.02451786]]
# Correlation coefficient
# -0.00047361317583
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06877975  0.03279624]
#  [ 0.05196797  0.0319983 ]]
# Correlation coefficient
# 0.000801965596995
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.02430726  0.01993376]
#  [ 0.06906966  0.02243647]]
# Correlation coefficient
# -0.000286282430475
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.02769241  0.04318527]
#  [ 0.08388939  0.01873911]]
# Correlation coefficient
# -0.000268788835941
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.08541504  0.01864886]
#  [ 0.09788135  0.05217861]]
# Correlation coefficient
# 0.00143671764119
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.0979085   0.0644361 ]
#  [ 0.07653372  0.0135269 ]]
# Correlation coefficient
# 0.0015690897297
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.03545263  0.02081769]
#  [ 0.03665262  0.02068549]]
# Correlation coefficient
# 0.0011679703245
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.03861849  0.04728367]
#  [ 0.01577327  0.07232249]]
# Correlation coefficient
# 0.000169336514028
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06099413  0.03388505]
#  [ 0.05709232  0.01845465]]
# Correlation coefficient
# 0.00133826729022
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06183518  0.09363666]
#  [ 0.03867121  0.07006693]]
# Correlation coefficient
# 0.000470949903735
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.02186181  0.07446945]
#  [ 0.03604655  0.02648722]]
# Correlation coefficient
# 0.000757426206278
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06278616  0.01180968]
#  [ 0.0846046   0.01042259]]
# Correlation coefficient
# 0.000776244491162
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.07100349  0.03430072]
#  [ 0.07616746  0.09659697]]
# Correlation coefficient
# 0.00139509888189
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.03238778  0.06185416]
#  [ 0.06328377  0.06150267]]
# Correlation coefficient
# 0.000256268493218
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.03007735  0.09574741]
#  [ 0.05024128  0.08617678]]
# Correlation coefficient
# 0.000539352871656
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.07295313  0.03676933]
#  [ 0.0832418   0.04568552]]
# Correlation coefficient
# 0.00139533466034
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.08929929  0.06231456]
#  [ 0.08935618  0.07232784]]
# Correlation coefficient
# 0.00122366622005
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.07527289  0.05511919]
#  [ 0.09604753  0.06795912]]
# Correlation coefficient
# 0.0008350544456
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.04814695  0.06457539]
#  [ 0.01172739  0.03714173]]
# Correlation coefficient
# -0.000606224483137
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06941562  0.03610698]
#  [ 0.06562139  0.04858918]]
# Correlation coefficient
# 0.00116148934254
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.02219267  0.03684541]
#  [ 0.06129684  0.06317855]]
# Correlation coefficient
# -0.00027076722888
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.06168927  0.06878807]
#  [ 0.06868929  0.04882766]]
# Correlation coefficient
# 0.00110154916164
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.09068919  0.04308057]
#  [ 0.04922784  0.0902731 ]]
# Correlation coefficient
# 0.000430820992753
#
#
#
# Initial guessed decomposition matrix:
# [[ 0.08255746  0.07334997]
#  [ 0.01902042  0.09275344]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-d716803f9721> in <module>()
#      22         elif i%10==0:
#      23             prevCost=cost
# ---> 24             cost=costFunc(Y,W)
#      25             if abs(abs(prevCost)-abs(cost)) < threshold:
#      26                 flag=False
#
# <ipython-input-60-64541712fc22> in costFunc(Y, W)
#       2     Z=sigmoid(Y)
#       3     c1=np.dot(Z.T,1-Z)
# ----> 4     C1=np.log(c1)
#       5     return np.sum(C1)
#
# KeyboardInterrupt:

# %%
print('Final decomposition matrix: \n',W)
Y2=np.dot(W,X)
print("Correlation coefficient \n" + str(np.corrcoef(Y2)[1][0]))
plt.figure()
plt.plot(Y2[0].T)
plt.show()
plt.figure()
plt.plot(Y2[1].T)
plt.show()
