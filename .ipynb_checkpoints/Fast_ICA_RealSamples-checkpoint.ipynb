# %%
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
import numpy as np
import wave as wv
import matplotlib.pyplot as plt
from scipy import signal
import scipy.io.wavfile
from sklearn.decomposition import FastICA

# %% [markdown]
# # Get samples from wav files

# %%
sourceFilesPrefix="AudioSources\\music-"
resultFilesPrefix="AudioResults\\music-"
rate1, sample1_data = scipy.io.wavfile.read(sourceFilesPrefix+"1.wav")
print(sample1_data.std(axis=0))
plt.figure(1)
plt.plot(sample1_data)
plt.title("data1")
plt.show()

rate2, sample2_data=scipy.io.wavfile.read(sourceFilesPrefix+"2.wav")
print(sample2_data.std(axis=0))
plt.figure(2)
plt.plot(sample2_data)
plt.title("data2")
plt.show()
# Out:
# 4678.62565787
# 2534.7114041

# %%
S=np.c_[sample1_data,sample2_data]
print(S)
median=S.std(axis=0)
print(median)
S= S/median

print(S)
# Out:
# [[ 3812  2732]
#  [ 5380  2868]
#  [ 4391  2564]
#  ...,
#  [-1756 -1198]
#  [-1939 -2648]
#  [-3867 -2960]]
# [ 4678.62565787  2534.7114041 ]
# [[ 0.81476918  1.07783474]
#  [ 1.14991034  1.13148976]
#  [ 0.93852347  1.011555  ]
#  ...,
#  [-0.37532389 -0.47263763]
#  [-0.41443794 -1.04469487]
#  [-0.82652477 -1.16778581]]

# %%
#print(S)
ica = FastICA(n_components=2,whiten=True)
S_=ica.fit_transform(S)
A_=ica.mixing_
M_=ica.mean_
print(A_)
print(M_)
# Out:
# [[ 286.14652934  167.69067877]
#  [ 327.93588973  -49.57874773]]
# [-0.00010699 -0.00020098]

# %%
plt.figure(3)
plt.plot(S_.T[0])
plt.title("rec1")
plt.show()
print(S_.T[0])
# Out:
# [ 0.00319719  0.00356744  0.00312522 ..., -0.00141411 -0.00282882
#  -0.00342253]

# %%
plt.figure(4)
plt.plot(S_.T[1])
plt.title("rec2")
plt.show()
print(S_.T[1])
# Out:
# [-0.00059627  0.00077051  0.00026453 ...,  0.00017547  0.00235628
#   0.00091196]

# %%
scipy.io.wavfile.write(resultFilesPrefix+"1.wav",16000,S_.T[0])

# %%
scipy.io.wavfile.write(resultFilesPrefix+"2.wav",16000,S_.T[1])
