# %%
import numpy as np
from scipy import signal
import scipy.io.wavfile
import matplotlib.pyplot as plt
import math
from IPython.display import Audio

# %%
def sigmoid(y):
    #g=np.zeros(y.shape)
    g=np.divide(1,np.add(1,np.exp(-y)))
    print(g)
    return g

def gradient(eta, Y, W):
    delW=np.zeros(W.shape)
    Z=sigmoid(Y)
    grad=np.multiply(np.multiply(eta,np.add(Id,(1-2*Z)*Y.T)),W)

# %%
sourceFilesPrefix="ExpectedResults\\music-"
resultFilesPrefix="AudioResults\\fromExpected-"
rate1, sample1_data = scipy.io.wavfile.read(sourceFilesPrefix+"1.wav")
print(sample1_data.std(axis=0))
#plt.figure(1)
#plt.plot(sample1_data)
#plt.title("data1")
#plt.show()

rate2, sample2_data=scipy.io.wavfile.read(sourceFilesPrefix+"2.wav")
print(sample2_data.std(axis=0))
#plt.figure(2)
#plt.plot(sample2_data)
#plt.title("data2")
#plt.show()
# Out:
# 5564.16372545
# 2619.18445716

# %%
S1=np.c_[sample1_data,sample2_data]
S2=np.c_[sample1_data,sample2_data]

plt.figure(1)
plt.plot(S2)
plt.show()
#S1/=S1.std(axis=0)
med1=S1.std(axis=0)
S1= S1/med1
#S2/=S2.std(axis=0)
med2=S2.std(axis=0)
S2=S2/med2

mixingMatrix1=np.array([1.1,0.7])
mixingMatrix2=np.array([1.5,0.5])
m=np.matrix([mixingMatrix1,mixingMatrix2])
X1=np.dot(S1,mixingMatrix1.T)
X2=np.dot(S2,mixingMatrix2.T)
plt.figure(2)
plt.plot(X1)
plt.plot(X2)
plt.show()
X=np.c_[X1,X2]
X=X.T

# %%
eta=0.01
eta0=eta
T=1000
num_iter=5000
W=np.random.random(m.shape)/30
#print("W "+str(W))
numSrc=X.shape[0]
print(numSrc)
b=np.ones((numSrc,1),float)
#print(W)
#print(b)
kappa=0.01
# Out:
# 2

# %%
def sigmoidB(B,y):
    #g=np.zeros(y.shape)
    #print("B"+str(B))
    #print("Y"+str(y))
    #print(-np.multiply(B,y))
    #print(np.exp(-np.multiply(B,y)))
    g=np.divide(1,np.add(1,np.exp(-(np.multiply(B,y)))))
    #print(g)
    return g

# %%
def wgradientbeta(eta,kappa,b, Y, W):
    delW=np.zeros(W.shape)
    B=np.kron(np.ones((1,Y.shape[1]),float),b)
    #print("B"+str(B))
    Z=sigmoidB(B,Y)
    #print("Z"+str(Z))
    Id=np.identity(Y.shape[0])
    a=(B*(1-2*Z))
    #print(a)
    l=np.dot(a,Y.conjugate().T)
    #print(l)
    grad=eta*(Id+l)*W
    #print("grad"+str(grad))
    #delmyW=eta*((np.multiply(B,(1-2*Z))*Y.T)+np.linalg.pinv(W).T)
    delb=np.dot(kappa,(np.sum((np.dot(Y*(1-2*Z),Y.conjugate().T)).conjugate().T)).conjugate().T)
    return (grad, 0,delb)

# %%
print(W)
for i in range(0,num_iter):
    Y=np.dot(W,X)
    (delW,delmyW,delb)=wgradientbeta(eta,kappa,b,Y,W)
    #print("W "+str(W))
    aux=W+delW
    W=aux
    #print("delW "+str(delW))
    eta=eta0/(1+(i/T))
    #print("eta "+str(eta))
    if i%100==0:
        print("W"+str(W))
        print("delW"+str(delW))
        #print(delb)
        b+=delb
# Out:
# delW[[  2.52744523e-09  -2.46426332e-09]
#  [ -1.16423501e-09   6.86293090e-50]]
# W[[  1.30193127e-02  -1.10660557e-02]
#  [ -8.66490893e-03  -2.11528561e-48]]
# delW[[  2.53750671e-09  -2.46921283e-09]
#  [ -1.18154246e-09   2.28272992e-50]]
# W[[  1.30196225e-02  -1.10663164e-02]
#  [ -8.66503858e-03  -7.30012216e-49]]
# delW[[  2.54723367e-09  -2.47392934e-09]
#  [ -1.19820328e-09   7.74052418e-51]]
# W[[  1.30199324e-02  -1.10665772e-02]
#  [ -8.66516950e-03  -2.56591450e-49]]
# delW[[  2.55664274e-09  -2.47842759e-09]
#  [ -1.21425264e-09   2.67404816e-51]]

# %%
print(W)
p=np.matrix([[0.013,-0.0106],[-0.008,-0.00927]])
Y2=np.dot(p,X)
print(Y2.T)
plt.figure(1)
plt.plot(Y2[0])
plt.plot(Y2[1])
plt.show()
# Out:
# [[  1.30202396e-02  -1.10668355e-02]
#  [ -8.66530044e-03  -9.27392004e-50]]
# [[ 0.00144791  0.01016048]
#  [ 0.00161414  0.0070813 ]
#  [ 0.00119383  0.00633446]
#  ...,
#  [-0.00055647 -0.01372672]
#  [-0.00071537 -0.01566317]
#  [-0.00067067 -0.01150139]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-164-7713a0069291> in <module>()
#       5 plt.figure(1)
#       6 plt.plot(Y2[0])
# ----> 7 plt.plot(Y2[1])
#       8 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1436
#    1437         for line in self._get_lines(*args, **kwargs):
# -> 1438             self.add_line(line)
#    1439             lines.append(line)
#    1440
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1755         self._set_artist_props(line)
#    1756         if line.get_clip_path() is None:
# -> 1757             line.set_clip_path(self.patch)
#    1758
#    1759         self._update_line_limits(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     652             if isinstance(path, Rectangle):
#     653                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 654                                                path.get_transform())
#     655                 self._clippath = None
#     656                 success = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     219         to the :class:`Patch`.
#     220         """
# --> 221         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     222
#     223     def get_data_transform(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     720
#     721     def get_patch_transform(self):
# --> 722         self._update_patch_transform()
#     723         return self._rect_transform
#     724
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     715         bbox = transforms.Bbox.from_bounds(x, y, width, height)
#     716         rot_trans = transforms.Affine2D()
# --> 717         rot_trans.rotate_deg_around(x, y, self.angle)
#     718         self._rect_transform = transforms.BboxTransformTo(bbox)
#     719         self._rect_transform += rot_trans
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    2036         # Cast to float to avoid wraparound issues with uint8's
#    2037         x, y = float(x), float(y)
# -> 2038         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    2039
#    2040     def translate(self, tx, ty):
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in rotate_deg(self, degrees)
#    2014         and :meth:`scale`.
#    2015         """
# -> 2016         return self.rotate(degrees * np.pi / 180.)
#    2017
#    2018     def rotate_around(self, x, y, theta):
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in rotate(self, theta)
#    2002         rotate_mtx = np.array([[a, -b, 0.0], [b, a, 0.0], [0.0, 0.0, 1.0]],
#    2003                               float)
# -> 2004         self._mtx = np.dot(rotate_mtx, self._mtx)
#    2005         self.invalidate()
#    2006         return self
#
# KeyboardInterrupt:

# %%
plt.figure(1)
m1=np.array([[0.154,-0.1109],[-0.0500,0.0533]])
print(m1)
y2=np.dot(m1,X)
print(y2.T)
plt.plot(y2.T)
plt.show()
# Out:
# [[ 0.154  -0.1109]
#  [-0.05    0.0533]]
# [[ 0.0068871  -0.01433753]
#  [ 0.01162134 -0.01261492]
#  [ 0.00757622 -0.01020054]
#  ...,
#  [ 0.00647594  0.01330324]
#  [ 0.00648306  0.01552842]
#  [ 0.00312144  0.01203256]]

# %%
Audio(data=Y2[0]*2, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=Y2[1]*2, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
