# %%
import numpy as np
from scipy import signal
import scipy.io.wavfile
import matplotlib.pyplot as plt
import math
from IPython.display import Audio

# %%
sourceFilesPrefix="ExpectedResults\\music-"
#sourceFilesPrefix="s"
resultFilesPrefix="AudioResults\\fromExpectedmatlab-"
rate1, sample1_data = scipy.io.wavfile.read(sourceFilesPrefix+"1.wav")
print(sample1_data.std(axis=0))
#plt.figure(1)
#plt.plot(sample1_data)
#plt.title("data1")
#plt.show()

rate2, sample2_data=scipy.io.wavfile.read(sourceFilesPrefix+"2.wav")
print(sample2_data.std(axis=0))
#plt.figure(2)
#plt.plot(sample2_data)
#plt.title("data2")
#plt.show()
# Out:
# 5564.16372545
# 2619.18445716

# %%
S1=np.c_[sample1_data,sample2_data]
S2=np.c_[sample1_data,sample2_data]

plt.figure(1)
plt.plot(sample1_data)
plt.show()
plt.figure(2)
plt.plot(sample2_data)
plt.show()
#S1/=S1.std(axis=0)
med1=S1.std(axis=0)
S1= S1/med1
#S2/=S2.std(axis=0)
med2=S2.std(axis=0)
S2=S2/med2

mixingMatrix1=np.array([1.1,0.7])
mixingMatrix2=np.array([1.5,0.5])
m=np.matrix([mixingMatrix1,mixingMatrix2])
X1=np.dot(S1,mixingMatrix1.T)
X2=np.dot(S2,mixingMatrix2.T)
#plt.figure(2)
#plt.plot(X1)
#plt.plot(X2)
#plt.show()
X=np.c_[X1,X2]
X=X.T

# %%
eta=0.01
eta0=eta
T=1000
num_iter=10000
W=np.random.random(m.shape)/50
A=np.random.random((2,2))
print(A)

med1=sample1_data.std(axis=0)
s1data= sample1_data/med1
med2=sample2_data.std(axis=0)
s2data=sample2_data/med2

orig=np.matrix([s1data,s2data])
X=np.dot(A,orig)
plt.figure(1)
plt.plot(X.T)
plt.show()
print(W)
#print("W "+str(W))
numSrc=X.shape[0]
print(numSrc)
#print(W)
#print(b)
# Out:
# [[ 0.40240763  0.57287136]
#  [ 0.85320705  0.59279913]]
# [[ 0.00549392  0.01734454]
#  [ 0.01410633  0.0177974 ]]
# 2

# %%
def sigmoid(y):
    #g=np.zeros(y.shape)
    g=np.divide(1,np.add(1,np.exp(-y)))
    #print(g)
    return g

def gradient(eta, Y, W):
    delW=np.zeros(W.shape)
    Z=sigmoid(Y)
    Id=np.identity(Y.shape[0])
    grad=eta*(Id+np.dot((1-2*Z),Y.T))*W
    return grad

# %%
print(W)
for i in range(0,num_iter):
    Y=np.dot(W,X)
    delW=gradient(eta,Y,W)
    aux=W+delW
    W=aux
    eta=eta0/(1+(i/T))
    if i%100==0:
        print("delW "+str(delW))
        print("W "+str(W))
    #print("eta "+str(eta))
# Out:
# [[ 0.00549392  0.01734454]
#  [ 0.01410633  0.0177974 ]]
# delW [[-0.00599535 -0.01012206]
#  [-0.00767362 -0.01311023]]
# W [[-0.00050142  0.00722247]
#  [ 0.00643271  0.00468717]]
# delW [[ -5.02767303e-05   2.94505171e-05]
#  [  3.58336930e-05  -2.80423133e-05]]
# W [[-0.00650952  0.00697734]
#  [ 0.00741412 -0.00136242]]
# delW [[ -2.90169780e-05   1.85581092e-05]
#  [  2.20503653e-05  -1.50659111e-05]]
# W [[-0.01070572  0.00958488]
#  [ 0.01053601 -0.0035957 ]]
# delW [[ -7.96390421e-06   5.13844465e-06]
#  [  6.09189994e-06  -4.10308767e-06]]
# W [[-0.01238142  0.01066184]
#  [ 0.01181403 -0.00446202]]
# delW [[ -1.81810739e-06   1.17490678e-06]
#  [  1.39276042e-06  -9.35782446e-07]]
# W [[-0.01279515  0.01092899]
#  [ 0.01213072 -0.00467504]]
# delW [[ -4.30899022e-07   2.78602484e-07]
#  [  3.30567779e-07  -2.22026816e-07]]
# W [[-0.01289026  0.01099047]
#  [ 0.01220361 -0.00472401]]
# delW [[ -1.10402657e-07   7.14380933e-08]
#  [  8.50592525e-08  -5.71596327e-08]]
# W [[-0.01291348  0.01100549]
#  [ 0.01222145 -0.00473599]]
# delW [[ -3.05072286e-08   1.97868849e-08]
#  [  2.38305405e-08  -1.60472588e-08]]
# W [[-0.01291962  0.01100946]
#  [ 0.0122262  -0.00473919]]
# delW [[ -8.95630222e-09   5.85162805e-09]
#  [  7.29616429e-09  -4.94387725e-09]]
# W [[-0.01292136  0.0110106 ]
#  [ 0.01222758 -0.00474012]]
# delW [[ -2.70845905e-09   1.80941585e-09]
#  [  2.48703729e-09  -1.71284228e-09]]
# W [[-0.01292188  0.01101094]
#  [ 0.01222802 -0.00474042]]
# delW [[ -7.78554948e-10   5.58885224e-10]
#  [  9.87960134e-10  -7.04281785e-10]]
# W [[-0.01292204  0.01101104]
#  [ 0.01222818 -0.00474053]]
# delW [[ -1.50042671e-10   1.49928953e-10]
#  [  4.87804859e-10  -3.66553225e-10]]
# W [[-0.01292208  0.01101107]
#  [ 0.01222825 -0.00474058]]
# delW [[  6.24178681e-11   1.01741382e-11]
#  [  3.08078425e-10  -2.44119943e-10]]
# W [[-0.01292208  0.01101108]
#  [ 0.01222828 -0.00474061]]
# delW [[  1.34761611e-10  -3.87912896e-11]
#  [  2.37171376e-10  -1.94895636e-10]]
# W [[-0.01292207  0.01101108]
#  [ 0.01222831 -0.00474063]]
# delW [[  1.57781662e-10  -5.56876238e-11]
#  [  2.05343008e-10  -1.72041295e-10]]
# W [[-0.01292205  0.01101107]
#  [ 0.01222833 -0.00474065]]
# delW [[  1.62846079e-10  -6.08150782e-11]
#  [  1.88406931e-10  -1.59303549e-10]]
# W [[-0.01292204  0.01101107]
#  [ 0.01222835 -0.00474066]]
# delW [[  1.61272656e-10  -6.15087796e-11]
#  [  1.77561175e-10  -1.50759648e-10]]
# W [[-0.01292202  0.01101106]
#  [ 0.01222837 -0.00474068]]
# delW [[  1.57299981e-10  -6.05246690e-11]
#  [  1.69446703e-10  -1.44142891e-10]]
# W [[-0.01292201  0.01101106]
#  [ 0.01222839 -0.00474069]]
# delW [[  1.52562287e-10  -5.89328048e-11]
#  [  1.62715717e-10  -1.38538445e-10]]
# W [[-0.01292199  0.01101105]
#  [ 0.0122284  -0.00474071]]
# delW [[  5.36668884e-11  -2.08064612e-11]
#  [  5.67083265e-11  -4.83227941e-11]]
# W [[-0.01292154  0.01101088]
#  [ 0.01222888 -0.00474111]]
# delW [[  5.30041991e-11  -2.05495503e-11]
#  [  5.60080320e-11  -4.77260638e-11]]
# W [[-0.01292153  0.01101087]
#  [ 0.01222889 -0.00474112]]
# delW [[  5.23576756e-11  -2.02989064e-11]
#  [  5.53248212e-11  -4.71438906e-11]]
# W [[-0.01292153  0.01101087]
#  [ 0.01222889 -0.00474112]]
# delW [[  5.17267334e-11  -2.00543029e-11]
#  [  5.46580765e-11  -4.65757483e-11]]
# W [[-0.01292152  0.01101087]
#  [ 0.0122289  -0.00474113]]
# delW [[  5.11108161e-11  -1.98155241e-11]
#  [  5.40072098e-11  -4.60211357e-11]]
# W [[-0.01292152  0.01101087]
#  [ 0.0122289  -0.00474113]]
# delW [[  5.05093932e-11  -1.95823644e-11]
#  [  5.33716605e-11  -4.54795751e-11]]
# W [[-0.01292151  0.01101087]
#  [ 0.01222891 -0.00474114]]
# delW [[  4.99219592e-11  -1.93546277e-11]
#  [  5.27508944e-11  -4.49506114e-11]]
# W [[-0.01292151  0.01101086]
#  [ 0.01222891 -0.00474114]]
# delW [[  4.93480313e-11  -1.91321271e-11]
#  [  5.21444014e-11  -4.44338099e-11]]
# W [[-0.0129215   0.01101086]
#  [ 0.01222892 -0.00474115]]
# delW [[  4.87871494e-11  -1.89146840e-11]
#  [  5.15516948e-11  -4.39287559e-11]]
# W [[-0.0129215   0.01101086]
#  [ 0.01222892 -0.00474115]]
# delW [[  4.82388734e-11  -1.87021278e-11]
#  [  5.09723101e-11  -4.34350536e-11]]
# W [[-0.01292149  0.01101086]
#  [ 0.01222893 -0.00474115]]
# delW [[  4.77027832e-11  -1.84942957e-11]
#  [  5.04058029e-11  -4.29523243e-11]]
# W [[-0.01292149  0.01101086]
#  [ 0.01222893 -0.00474116]]
# delW [[  4.71784770e-11  -1.82910320e-11]
#  [  4.98517488e-11  -4.24802063e-11]]
# W [[-0.01292148  0.01101085]
#  [ 0.01222894 -0.00474116]]
# delW [[  4.66655704e-11  -1.80921876e-11]
#  [  4.93097415e-11  -4.20183536e-11]]
# W [[-0.01292148  0.01101085]
#  [ 0.01222894 -0.00474117]]
# delW [[  4.61636957e-11  -1.78976199e-11]
#  [  4.87793924e-11  -4.15664349e-11]]
# W [[-0.01292147  0.01101085]
#  [ 0.01222895 -0.00474117]]
# delW [[  4.56725007e-11  -1.77071925e-11]
#  [  4.82603294e-11  -4.11241332e-11]]
# W [[-0.01292147  0.01101085]
#  [ 0.01222895 -0.00474118]]
# delW [[  4.51916482e-11  -1.75207747e-11]
#  [  4.77521960e-11  -4.06911446e-11]]
# W [[-0.01292147  0.01101085]
#  [ 0.01222896 -0.00474118]]
# delW [[  4.47208149e-11  -1.73382409e-11]
#  [  4.72546506e-11  -4.02671782e-11]]
# W [[-0.01292146  0.01101085]
#  [ 0.01222896 -0.00474118]]
# delW [[  4.42596909e-11  -1.71594713e-11]
#  [  4.67673657e-11  -3.98519549e-11]]
# W [[-0.01292146  0.01101084]
#  [ 0.01222897 -0.00474119]]
# delW [[  4.38079789e-11  -1.69843504e-11]
#  [  4.62900271e-11  -3.94452069e-11]]
# W [[-0.01292145  0.01101084]
#  [ 0.01222897 -0.00474119]]
# delW [[  4.33653938e-11  -1.68127677e-11]
#  [  4.58223335e-11  -3.90466774e-11]]
# W [[-0.01292145  0.01101084]
#  [ 0.01222898 -0.0047412 ]]
# delW [[  4.29316615e-11  -1.66446171e-11]
#  [  4.53639953e-11  -3.86561198e-11]]
# W [[-0.01292144  0.01101084]
#  [ 0.01222898 -0.0047412 ]]
# delW [[  4.25065192e-11  -1.64797966e-11]
#  [  4.49147347e-11  -3.82732973e-11]]
# W [[-0.01292144  0.01101084]
#  [ 0.01222899 -0.0047412 ]]
# delW [[  4.20897142e-11  -1.63182083e-11]
#  [  4.44742847e-11  -3.78979824e-11]]
# W [[-0.01292143  0.01101084]
#  [ 0.01222899 -0.00474121]]
# delW [[  4.16810036e-11  -1.61597579e-11]
#  [  4.40423886e-11  -3.75299563e-11]]
# W [[-0.01292143  0.01101083]
#  [ 0.012229   -0.00474121]]
# delW [[  4.12801538e-11  -1.60043550e-11]
#  [  4.36187996e-11  -3.71690088e-11]]
# W [[-0.01292143  0.01101083]
#  [ 0.012229   -0.00474122]]
# delW [[  4.08869404e-11  -1.58519125e-11]
#  [  4.32032804e-11  -3.68149376e-11]]
# W [[-0.01292142  0.01101083]
#  [ 0.012229   -0.00474122]]
# delW [[  4.05011470e-11  -1.57023466e-11]
#  [  4.27956024e-11  -3.64675481e-11]]
# W [[-0.01292142  0.01101083]
#  [ 0.01222901 -0.00474122]]
# delW [[  4.01225658e-11  -1.55555766e-11]
#  [  4.23955459e-11  -3.61266528e-11]]
# W [[-0.01292141  0.01101083]
#  [ 0.01222901 -0.00474123]]
# delW [[  3.97509962e-11  -1.54115250e-11]
#  [  4.20028991e-11  -3.57920715e-11]]
# W [[-0.01292141  0.01101083]
#  [ 0.01222902 -0.00474123]]
# delW [[  3.93862453e-11  -1.52701167e-11]
#  [  4.16174580e-11  -3.54636302e-11]]
# W [[-0.01292141  0.01101082]
#  [ 0.01222902 -0.00474123]]

# %%
print(W)
#p=np.matrix([W[0],W[1]])
#p[1,1]=0.0268169
#p=p*10
#print(p)
Y2=np.dot(W*10,X)
print(Y2.T)
plt.figure(1)
plt.plot(Y2.T)
plt.show()
# Out:
# [[-0.0129214   0.01101082]
#  [ 0.01222903 -0.00474124]]
# [[-0.02324966  0.00223277]
#  [-0.01990523  0.00664157]
#  [-0.01627597  0.00383916]
#  ...,
#  [ 0.02284722  0.00874801]
#  [ 0.02656216  0.00930633]
#  [ 0.02039386  0.00561167]]

# %%
Audio(data=X[0], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=X[1], rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=Y2[0]*2, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=Y2[1]*2, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=sample1_data, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=sample2_data, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
