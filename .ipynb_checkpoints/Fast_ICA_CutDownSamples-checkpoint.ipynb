# %%
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
import numpy as np
import wave as wv
import matplotlib.pyplot as plt
from scipy import signal
import scipy.io.wavfile
from sklearn.decomposition import FastICA

# %% [markdown]
# # Get samples from wav files

# %%
sourceFilesPrefix="AudioSources\\oneNumber-"
resultFilesPrefix="AudioResults\\oneNumber-"
rate1, sample1_data = scipy.io.wavfile.read(sourceFilesPrefix+"1.wav")
print(sample1_data.std(axis=0))
plt.figure(1)
plt.plot(sample1_data)
plt.title("data1")
plt.show()

rate2, sample2_data=scipy.io.wavfile.read(sourceFilesPrefix+"2.wav")
print(sample2_data.std(axis=0))
plt.figure(2)
plt.plot(sample2_data)
plt.title("data2")
plt.show()
# Out:
# 6121.11973246
# 4540.79015605

# %%
S=np.c_[sample1_data,sample2_data]
print(S)
median=S.std(axis=0)
print(median)
S= S/median

print(S)
# Out:
# [[148 159]
#  [174 141]
#  [195 159]
#  ...,
#  [-19  66]
#  [ -7  68]
#  [ 17 124]]
# [ 6121.11973246  4540.79015605]
# [[ 0.02417858  0.03501593]
#  [ 0.02842617  0.03105186]
#  [ 0.03185692  0.03501593]
#  ...,
#  [-0.00310401  0.01453492]
#  [-0.00114358  0.01497537]
#  [ 0.00277727  0.02730802]]

# %%
ica = FastICA(n_components=2)
S_=ica.fit_transform(S)
A_=ica.mixing_
M_=ica.mean_
print(A_)
print(M_)
# Out:
# [[ -80.45010661  -79.56620103]
#  [  -0.60479583 -113.14872612]]
# [  3.00604721e-04   7.83339179e-05]

# %%
plt.figure(3)
plt.plot(S_.T[0])
plt.title("rec1")
plt.show()
print(S_.T[0])
# Out:
# [  8.62415296e-06  -7.92876029e-05  -8.73252572e-05 ...,   1.69578427e-04
#    1.48951078e-04   2.08326084e-04]

# %%
plt.figure(4)
plt.plot(S_.T[1])
plt.title("rec2")
plt.show()
print(S_.T[1])
# Out:
# [-0.00030882 -0.00027332 -0.00030831 ..., -0.00012867 -0.00013246
#  -0.00024177]

# %%
scipy.io.wavfile.write(resultFilesPrefix+"1.wav",16000,S_.T[0])

# %%
scipy.io.wavfile.write(resultFilesPrefix+"2.wav",16000,S_.T[1])
